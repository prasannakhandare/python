# %%
## Importing libarares

# %%
# !pip install Pandas

# %%
import pandas as pd

import warnings

warnings.filterwarnings('ignore')

# %%
lst = [1,2,3,4,5]
type(lst)
# Out:
# list

# %%
s = pd.Series(lst)
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s = pd.Series(data = ['A',10,2500])
s
# Out:
# 0       A
# 1      10
# 2    2500
# dtype: object

# %%
d = {1:'A',2:'B',3:'C'}
type(d)
# Out:
# dict

# %%
s = pd.Series(d)
s
# Out:
# 1    A
# 2    B
# 3    C
# dtype: object

# %%
s = pd.Series(data = [10,20,30], index= ['A','B','C'],name = 'Mu_series')
s
# Out:
# A    10
# B    20
# C    30
# Name: Mu_series, dtype: int64

# %%
s['A']
# Out:
# 10

# %%
s[0]
# Out:
# 10

# %%
s[0:2]
# Out:
# A    10
# B    20
# Name: Mu_series, dtype: int64

# %% [markdown]
# # DATA FRAME

# %%
lst = [['Python',90,'pune'],['ML',100,'Mumbai'],['DL',95,'HYD']]

col = ['Subject','Marks','City']
Sr = [1,2,3]

# %%
df = pd.DataFrame(data =lst, columns=col, index = Sr)

# %%
df
# Out:
#   Subject  Marks    City
# 1  Python     90    pune
# 2      ML    100  Mumbai
# 3      DL     95     HYD

# %%
df = pd.DataFrame({
    'Subject' : ['Python','ML','DL'],
    'Marks'   : [90,70,100],
    'City Name'    : ['Pune','Mumbai','HYD']
})

# %%
df
# Out:
#   Subject  Marks City Name
# 0  Python     90      Pune
# 1      ML     70    Mumbai
# 2      DL    100       HYD

# %%
df.shape
# Out:
# (3, 3)

# %%
df.ndim
# Out:
# 2

# %%
df.dtypes
# Out:
# Subject      object
# Marks         int64
# City Name    object
# dtype: object

# %%
df.Subject
# Out:
# 0    Python
# 1        ML
# 2        DL
# Name: Subject, dtype: object

# %%
df['Subject']
# Out:
# 0    Python
# 1        ML
# 2        DL
# Name: Subject, dtype: object

# %%
df['City Name']
# Out:
# 0      Pune
# 1    Mumbai
# 2       HYD
# Name: City Name, dtype: object

# %%
df[['Marks']]
# Out:
#    Marks
# 0     90
# 1     70
# 2    100

# %%
df.describe()
# Out:
#             Marks
# count    3.000000
# mean    86.666667
# std     15.275252
# min     70.000000
# 25%     80.000000
# 50%     90.000000
# 75%     95.000000
# max    100.000000

# %%
df.describe(include='O')
# Out:
#        Subject City Name
# count        3         3
# unique       3         3
# top     Python      Pune
# freq         1         1

# %%
df.describe(include='all')
# Out:
#        Subject       Marks City Name
# count        3    3.000000         3
# unique       3         NaN         3
# top     Python         NaN      Pune
# freq         1         NaN         1
# mean       NaN   86.666667       NaN
# std        NaN   15.275252       NaN
# min        NaN   70.000000       NaN
# 25%        NaN   80.000000       NaN
# 50%        NaN   90.000000       NaN
# 75%        NaN   95.000000       NaN
# max        NaN  100.000000       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Subject    3 non-null      object
#  1   Marks      3 non-null      int64
#  2   City Name  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
df.isnull().sum()
# Out:
# Subject      0
# Marks        0
# City Name    0
# dtype: int64

# %%
pk= pd.read_csv('Salaries.csv')

# %%
pk
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
pk.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
pk.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
pk.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
pk.tail(10)
# Out:
#          rank discipline  phd  service     sex  salary
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
pd.set_option('display.max_rows',None)

# %%
pk
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
pk.describe(include='all')
# Out:
#         rank discipline        phd    service   sex         salary
# count     78         78  78.000000  78.000000    78      78.000000
# unique     3          2        NaN        NaN     2            NaN
# top     Prof          B        NaN        NaN  Male            NaN
# freq      46         42        NaN        NaN    39            NaN
# mean     NaN        NaN  19.705128  15.051282   NaN  108023.782051
# std      NaN        NaN  12.498425  12.139768   NaN   28293.661022
# min      NaN        NaN   1.000000   0.000000   NaN   57800.000000
# 25%      NaN        NaN  10.250000   5.250000   NaN   88612.500000
# 50%      NaN        NaN  18.500000  14.500000   NaN  104671.000000
# 75%      NaN        NaN  27.750000  20.750000   NaN  126774.750000
# max      NaN        NaN  56.000000  51.000000   NaN  186960.000000

# %%
pk.describe(include='all').T
# Out:
#            count unique   top freq           mean           std      min  \
# rank          78      3  Prof   46            NaN           NaN      NaN
# discipline    78      2     B   42            NaN           NaN      NaN
# phd         78.0    NaN   NaN  NaN      19.705128     12.498425      1.0
# service     78.0    NaN   NaN  NaN      15.051282     12.139768      0.0
# sex           78      2  Male   39            NaN           NaN      NaN
# salary      78.0    NaN   NaN  NaN  108023.782051  28293.661022  57800.0
#
#                 25%       50%        75%       max
# rank            NaN       NaN        NaN       NaN
# discipline      NaN       NaN        NaN       NaN
# phd           10.25      18.5      27.75      56.0
# service        5.25      14.5      20.75      51.0
# sex             NaN       NaN        NaN       NaN
# salary      88612.5  104671.0  126774.75  186960.0

# %%
pk.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
pk[['phd','salary']]
# Out:
#     phd  salary
# 0    56  186960
# 1    12   93000
# 2    23  110515
# 3    40  131205
# 4    20  104800
# 5    20  122400
# 6    20   81285
# 7    18  126300
# 8    29   94350
# 9    51   57800
# 10   39  128250
# 11   23  134778
# 12    1   88000
# 13   35  162200
# 14   25  153750
# 15   17  150480
# 16    8   75044
# 17    4   92000
# 18   19  107300
# 19   29  150500
# 20    4   92000
# 21   33  103106
# 22    4   73000
# 23    2   85000
# 24   30   91100
# 25   35   99418
# 26   38  148750
# 27   45  155865
# 28    7   91300
# 29   21  123683
# 30    9  107008
# 31   22  155750
# 32   27  103275
# 33   18  120000
# 34   12  119800
# 35   28  126933
# 36   45  146856
# 37   20  102000
# 38    4   91000
# 39   18  129000
# 40   39  137000
# 41   13   74830
# 42    4   80225
# 43    5   77000
# 44   23  151768
# 45   25  140096
# 46   11   74692
# 47   11  103613
# 48   17  111512
# 49   17  122960
# 50   10   97032
# 51   20  127512
# 52   12  105000
# 53    5   73500
# ...

# %% [markdown]
# * LOC function

# %%
pk.loc[10:15,'phd']
# Out:
# 10    39
# 11    23
# 12     1
# 13    35
# 14    25
# 15    17
# Name: phd, dtype: int64

# %%
pk.loc[10:15,'phd':'salary']
# Out:
#     phd  service   sex  salary
# 10   39       33  Male  128250
# 11   23       23  Male  134778
# 12    1        0  Male   88000
# 13   35       33  Male  162200
# 14   25       19  Male  153750
# 15   17        3  Male  150480

# %%
pk.loc[[10,15],'phd':'salary']
# Out:
#     phd  service   sex  salary
# 10   39       33  Male  128250
# 15   17        3  Male  150480

# %%
pk.loc[[10,15],['phd','salary']]
# Out:
#     phd  salary
# 10   39  128250
# 15   17  150480

# %%
pk.iloc[50:56,0:3]
# Out:
#          rank discipline  phd
# 50   AsstProf          B   10
# 51       Prof          B   20
# 52       Prof          A   12
# 53   AsstProf          A    5
# 54  AssocProf          A   25
# 55   AsstProf          A    2

# %%
pk.iloc[[50,56],[0,3]]
# Out:
#          rank  service
# 50   AsstProf        5
# 56  AssocProf        8

# %%
pk['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
pk['discipline'].value_counts()
# Out:
# B    42
# A    36
# Name: discipline, dtype: int64

# %%
pk['sex'].value_counts()
# Out:
# Male      39
# Female    39
# Name: sex, dtype: int64

# %%
pk.value_counts('rank')
# Out:
# rank
# Prof         46
# AsstProf     19
# AssocProf    13
# dtype: int64

# %%
pk.rename(columns= {'rank':'Rank'})
# Out:
#          Rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
pk.rename(columns= {'discipline':'Discipline','phd':'PHD'},inplace=True)

# %%
pk
# Out:
#          rank Discipline  PHD  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
pk.rename(columns= {'rank':'Rank','sex':'SEX'},inplace=True)

# %%
pk
# Out:
#          Rank Discipline  PHD  service     SEX  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
pk.rename(columns= {'service ':'Service ','salary':'Salary'},inplace=True)

# %%
pk
# Out:
#          Rank Discipline  PHD  service     SEX  Salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %% [markdown]
#  * Filterring

# %%
pk['phd'].mean()
# Out:
# 19.705128205128204

# %%
pk.mean()
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
pk.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
pk[pk['sex']== 'Female']
# Out:
#          rank discipline  phd  service     sex  salary
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000
# 44       Prof          B   23       19  Female  151768
# 45       Prof          B   25       25  Female  140096
# 46   AsstProf          B   11        3  Female   74692
# 47  AssocProf          B   11       11  Female  103613
# 48       Prof          B   17       17  Female  111512
# 49       Prof          B   17       18  Female  122960
# 50   AsstProf          B   10        5  Female   97032
# 51       Prof          B   20       14  Female  127512
# 52       Prof          A   12        0  Female  105000
# 53   AsstProf          A    5        3  Female   73500
# 54  AssocProf          A   25       22  Female   62884
# ...

# %%
pk[(pk['sex']== 'Female') & (pk['salary']>150000)]
# Out:
#     rank discipline  phd  service     sex  salary
# 44  Prof          B   23       19  Female  151768
# 72  Prof          B   24       15  Female  161101

# %%
pk[(pk['sex']== 'Female') |(pk['salary']>150000)] # THIS IS NOT VALID COMMAND for using or operator it should be and operator
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# 19       Prof          A   29       27    Male  150500
# 27       Prof          A   45       43    Male  155865
# 31       Prof          B   22       21    Male  155750
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000
# 44       Prof          B   23       19  Female  151768
# 45       Prof          B   25       25  Female  140096
# 46   AsstProf          B   11        3  Female   74692
# 47  AssocProf          B   11       11  Female  103613
# ...

# %%
df1 = pk[(pk['sex']== 'Female') & (pk['salary']>150000)]

# %%
df1[['service','phd']]
# Out:
#     service  phd
# 44       19   23
# 72       15   24

# %%
#what is the ave salary of female?

# %%
avg_female = pk[pk['sex']=='Female']['salary'].mean()
print ('the avrage salary of female is :', avg_female)
# Out:
# the avrage salary of female is : 101002.41025641025

# %%
pk[pk['sex']=='Male']['salary'].median()
# Out:
# 107300.0

# %%
#what is ave of rank prof

# %%
pk['rank'].unique()
# Out:
# array(['Prof', 'AssocProf', 'AsstProf'], dtype=object)

# %%
pk['rank'].nunique()
# Out:
# 3

# %%
pk[pk['rank']=='Prof']['salary'].mean()
# Out:
# 123624.80434782608

# %%
pk[(pk['rank']=='Prof') & (pk['discipline']=='A')]
# Out:
#     rank discipline  phd  service     sex  salary
# 1   Prof          A   12        6    Male   93000
# 2   Prof          A   23       20    Male  110515
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 8   Prof          A   29       19    Male   94350
# 9   Prof          A   51       51    Male   57800
# 18  Prof          A   19        7    Male  107300
# 19  Prof          A   29       27    Male  150500
# 21  Prof          A   33       30    Male  103106
# 24  Prof          A   30       23    Male   91100
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 32  Prof          A   27       19    Male  103275
# 37  Prof          A   20        8    Male  102000
# 40  Prof          A   39       36  Female  137000
# 52  Prof          A   12        0  Female  105000
# 63  Prof          A   29       27  Female   91000
# ...

# %%
pk[(pk['rank']=='Prof') & (pk['discipline']=='A')]['salary'].mean()
# Out:
# 111935.69565217392

# %%
pk[pk['rank']=='AssocProf']['salary'].mean()
# Out:
# 91786.23076923077

# %%
pk[pk['rank']== 'AsstProf']['salary'].mean()
# Out:
# 81362.78947368421

# %% [markdown]
# # Group by function

# %%
pk.groupby('rank')['salary'].mean()
# Out:
# rank
# AssocProf     91786.230769
# AsstProf      81362.789474
# Prof         123624.804348
# Name: salary, dtype: float64

# %%
pk.groupby('rank')['salary'].agg({'min','max','mean','median'})
# Out:
#               max    min    median           mean
# rank
# AssocProf  119800  62884  103613.0   91786.230769
# AsstProf    97032  63100   78500.0   81362.789474
# Prof       186960  57800  123321.5  123624.804348

# %%
pk1= pd.read_csv('nba.csv')

# %%
pk1
# Out:
#                          Name                    Team  Number Position   Age  \
# 0               Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                 Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2                John Holland          Boston Celtics    30.0       SG  27.0
# 3                 R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4               Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5                Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6               Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7                Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8                Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9                Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10            Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
pk1.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
pk1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
pk1.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
#Extract the data where team is bostan celtic and weight is less than 100
# what is the avrage salary pf players of team los angeles lakers.
#What is the avrage salary of players based of various possition.

# %%
pk1[(pk1['Team']== 'Boston Celtics') & (pk1['Weight']<100)]
# Out:
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Height, Weight, College, Salary]
# Index: []

# %%
avg_salary = pk1[pk1['Team']=='Los Angeles Lakers']['Salary'].mean()
print ('the avrage salary of players is :', avg_salary)
# Out:
# the avrage salary of players is : 4784695.4

# %%
pk1.groupby('Position')['Salary'].mean()
# Out:
# Position
# C     5.967052e+06
# PF    4.562483e+06
# PG    5.077829e+06
# SF    4.857393e+06
# SG    4.009861e+06
# Name: Salary, dtype: float64

# %%
pk1[[San]]
